# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.tail()
# Out:
#     id          state abbr  poverty  povertyMoe   age  ageMoe   income  \
# 47  53     Washington   WA     13.2         0.4  37.5     0.1  61366.0
# 48  54  West Virginia   WV     18.3         0.7  41.9     0.2  41059.0
# 49  55      Wisconsin   WI     13.2         0.4  39.2     0.2  52622.0
# 50  56        Wyoming   WY     11.2         0.9  36.6     0.4  57055.0
# 51  vv            NaN  NaN      NaN         NaN   NaN     NaN      NaN
#
#     incomeMoe  healthcare  healthcareLow  healthcareHigh  obesity  obesityLow  \
# 47      485.0        10.7            9.7            11.8     27.3        26.0
# 48      651.0        10.1            9.1            11.2     35.7        34.2
# 49      433.0         8.5            7.4             9.7     31.2        29.6
# 50     1983.0        15.1           13.3            16.9     29.5        27.4
# 51        NaN         NaN            NaN             NaN      NaN         NaN
#
#     obesityHigh  smokes  smokesLow  smokesHigh  -0.385218228
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 19 columns):
# id                52 non-null object
# state             51 non-null object
# abbr              51 non-null object
# poverty           51 non-null float64
# povertyMoe        51 non-null float64
# age               51 non-null float64
# ageMoe            51 non-null float64
# income            51 non-null float64
# incomeMoe         51 non-null float64
# healthcare        51 non-null float64
# healthcareLow     51 non-null float64
# healthcareHigh    51 non-null float64
# obesity           51 non-null float64
# obesityLow        51 non-null float64
# obesityHigh       51 non-null float64
# smokes            51 non-null float64
# smokesLow         51 non-null float64
# smokesHigh        51 non-null float64
# -0.385218228      0 non-null float64
# dtypes: float64(16), object(3)
# memory usage: 7.8+ KB

# %%
# Delete the last row
df= df[:-1]

# %%
df['abbr'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
df.tail()
# Out:
#     id          state abbr  poverty  povertyMoe   age  ageMoe   income  \
# 46  51       Virginia   VA     11.8         0.3  37.7     0.1  64902.0
# 47  53     Washington   WA     13.2         0.4  37.5     0.1  61366.0
# 48  54  West Virginia   WV     18.3         0.7  41.9     0.2  41059.0
# 49  55      Wisconsin   WI     13.2         0.4  39.2     0.2  52622.0
# 50  56        Wyoming   WY     11.2         0.9  36.6     0.4  57055.0
#
#     incomeMoe  healthcare  healthcareLow  healthcareHigh  obesity  obesityLow  \
# 46      624.0        13.1           12.0            14.1     28.5        27.2
# 47      485.0        10.7            9.7            11.8     27.3        26.0
# 48      651.0        10.1            9.1            11.2     35.7        34.2
# 49      433.0         8.5            7.4             9.7     31.2        29.6
# 50     1983.0        15.1           13.3            16.9     29.5        27.4
#
#     obesityHigh  smokes  smokesLow  smokesHigh  -0.385218228
# ...

# %%
# Save the cleaned dataframe as csv, cover the original file
df.to_csv("data_clean.csv",index=False)
